# %%
data = [
  {'metric': 'annual_cost', 'display': 'Annual Cost'},
  {'metric': 'associates', 'display': '% Associates'},
  {'metric': 'bachelors', 'display': '% Bachelors'},
  {'metric': 'cost_index', 'display': 'Cost Index'},
  {'metric': 'crime_index', 'display': 'Crime Index'},
  {'metric': 'crime_per_100k', 'display': 'Crime Per 100k'},
  {'metric': 'doctorate', 'display': '% Doctorate'},
  {'metric': 'high_school', 'display': '% High School'},
  {'metric': 'masters', 'display': '% Masters'},
  {'metric': 'mean_hours_worked', 'display': 'Mean Hours Worked'},
  {'metric': 'med_gross_rent_pct_hshld_income', 'display': 'Med Gross Rent Pct Hshld Income'},
  {'metric': 'med_inc_accommodation_food_services', 'display': 'Med Inc Accommodation Food Services'},
  {'metric': 'med_inc_administrative_support_waste_management_services', 'display': 'Med Inc Administrative Support Waste Management Services'},
  {'metric': 'med_inc_agriculture_forestry_fishing_hunting', 'display': 'Med Inc Agriculture Forestry Fishing Hunting'},
  {'metric': 'med_inc_arts_entertainment_recreation', 'display': 'Med Inc Arts Entertainment Recreation'},
  {'metric': 'med_inc_construction', 'display': 'Med Inc Construction'},
  {'metric': 'med_inc_educational_services', 'display': 'Med Inc Educational Services'},
  {'metric': 'med_inc_finance_insurance', 'display': 'Med Inc Finance Insurance'},
  {'metric': 'med_inc_health_care_social_assistance', 'display': 'Med Inc Health Care Social Assistance'},
  {'metric': 'med_inc_information', 'display': 'Med Inc Information'},
  {'metric': 'med_inc_management_of_companies_enterprises', 'display': 'Med Inc Management Of Companies Enterprises'},
  {'metric': 'med_inc_manufacturing', 'display': 'Med Inc Manufacturing'},
  {'metric': 'med_inc_mining_quarrying_oil_gas_extraction', 'display': 'Med Inc Mining Quarrying Oil Gas Extraction'},
  {'metric': 'med_inc_other_services_except_public_administration', 'display': 'Med Inc Other Services Except Public Administration'},
  {'metric': 'med_inc_professional_scientific_technical_services', 'display': 'Med Inc Professional Scientific Technical Services'},
  {'metric': 'med_inc_public_administration', 'display': 'Med Inc Public Administration'},
  {'metric': 'med_inc_real_estate_rental_leasing', 'display': 'Med Inc Real Estate Rental Leasing'},
  {'metric': 'med_inc_retail_trade', 'display': 'Med Inc Retail Trade'},
  {'metric': 'med_inc_transportation_warehousing', 'display': 'Med Inc Transportation Warehousing'},
  {'metric': 'med_inc_utilities', 'display': 'Med Inc Utilities'},
  {'metric': 'med_inc_wholesale_trade', 'display': 'Med Inc Wholesale Trade'},
  {'metric': 'median_age', 'display': 'Median Age'},
  {'metric': 'median_commute', 'display': 'Median Commute'},
  {'metric': 'median_contract_rent', 'display': 'Median Contract Rent'},
  {'metric': 'median_household_income', 'display': 'Median Household Income'},
  {'metric': 'median_monthly_housing_costs', 'display': 'Median Monthly Housing Costs'},
  {'metric': 'pct_minority', 'display': '% Minority'},
  {'metric': 'per_capita_income', 'display': 'Per Capita Income'},
  {'metric': 'total_population', 'display': 'Total Population'},
  {'metric': 'unemployment_rate', 'display': 'Unemployment Rate'}
]

# %%
fields = {}
for el in data:
    el['isIncome'] = el['metric'][0:7] == 'med_inc'
    fields[el['metric']] = el

import json
print(json.dumps(fields,indent=4))
# Out:
# {
#     "annual_cost": {
#         "metric": "annual_cost",
#         "display": "Annual Cost",
#         "isIncome": false
#     },
#     "associates": {
#         "metric": "associates",
#         "display": "% Associates",
#         "isIncome": false
#     },
#     "bachelors": {
#         "metric": "bachelors",
#         "display": "% Bachelors",
#         "isIncome": false
#     },
#     "cost_index": {
#         "metric": "cost_index",
#         "display": "Cost Index",
#         "isIncome": false
#     },
#     "crime_index": {
#         "metric": "crime_index",
#         "display": "Crime Index",
#         "isIncome": false
#     },
#     "crime_per_100k": {
#         "metric": "crime_per_100k",
#         "display": "Crime Per 100k",
#         "isIncome": false
#     },
#     "doctorate": {
#         "metric": "doctorate",
#         "display": "% Doctorate",
#         "isIncome": false
#     },
#     "high_school": {
#         "metric": "high_school",
# ...
